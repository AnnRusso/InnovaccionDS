# %% [markdown]
# # Prácticas de Computer Vision

# %%
# Establecemos nuetras credenciales
cog_key='14c1f99e67774859ba79f7e0ba12b150'
cog_endpoint='https://hi-2252.cognitiveservices.azure.com/'

# %%
# Instalamos la biblioteca de Computer Vision
# !pip install --upgrade azure-cognitiveservices-vision-computervision
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Anahi\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...

# %%
cog_key='14c1f99e67774859ba79f7e0ba12b150'
cog_endpoint='https://hi-2252.cognitiveservices.azure.com/'

print('Ready to use cognitive services at {} using key {}'.format(cog_endpoint, cog_key))
#Ready to use cognitive services at https://https://hi-2252.cognitiveservices.azure.com/ using key 14c1f99e67774859ba79f7e0ba12b150
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from msrest.authentication import CognitiveServicesCredentials
import vision
import os

# %matplotlib inline

# Obtener la ruta de un archivo de imagen
image_path ='./data/vision/humana.jpg'

# Obtener un cliente del servicio Computer Vision
computervision_client = ComputerVisionClient(cog_endpoint, CognitiveServicesCredentials(cog_key))

# Obtener una descripción del servicio Computer Vision
image_stream = open(image_path, "rb")
description = computervision_client.describe_image_in_stream(image_stream)
print(description)

# Mostrar una imagen y un subtítulo (código en helper_scripts/vision.py)
vision.show_image_caption(image_path, description)
# Out:
# Ready to use cognitive services at https://hi-2252.cognitiveservices.azure.com/ using key 14c1f99e67774859ba79f7e0ba12b150
# {'additional_properties': {}, 'tags': ['text', 'person', 'shelf', 'indoor', 'scene', 'store', 'marketplace', 'shop'], 'captions': [<azure.cognitiveservices.vision.computervision.models._models_py3.ImageCaption object at 0x00000263E5595990>], 'request_id': '45c95c67-fc37-4c5c-a3a4-d9b997caf34b', 'metadata': <azure.cognitiveservices.vision.computervision.models._models_py3.ImageMetadata object at 0x00000263E5594C40>, 'model_version': '2021-05-01'}

# %%
# Obtener la ruta de un archivo de imagen
image_path ='./data/vision/humanos.jpg'

# Obtener una descripción del servicio Computer Vision
image_stream = open(image_path, "rb")
description = computervision_client.describe_image_in_stream(image_stream)

# Mostrar una imagen y un subtítulo (código en helper_scripts/vision.py)
vision.show_image_caption(image_path, description)

# %%
# Obtener la ruta de un archivo de imagen
image_path ='./data/vision/humanos.jpg'

# Indicar las características que se quieren analizar
features = ['Description', 'Tags', 'Adult', 'Objects', 'Faces']

# Obtener un análisis del servicio Computer Vision
image_stream = open(image_path, "rb")
analysis = computervision_client.analyze_image_in_stream(image_stream, visual_features=features)

# Mostrar los resultados del análisis (código en helper_scripts/vision.py)
vision.show_image_analysis(image_path, analysis)

# %% [markdown]
# # FaceAPI
# !pip install azure-cognitiveservices-vision-face

# %%
# !pip install azure-cognitiveservices-vision-face
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Anahi\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
cog_key = '5dec23bff95f4109ba2ece677e2a9572'
cog_endpoint = 'https://face-dr-lab2.cognitiveservices.azure.com/'

# %%
from azure.cognitiveservices.vision.face import FaceClient
from msrest.authentication import CognitiveServicesCredentials
import faces
import os
# %matplotlib inline

# Crear un cliente de detección facial.
client = FaceClient(cog_endpoint, CognitiveServicesCredentials(cog_key))

# %%
# Abrir una imagen
image_path ='./data/vision/humanos.jpg'
image_stream = open(image_path, "rb")

# Detectar caras
detected_faces = client.face.detect_with_stream(image=image_stream)

# Mostrar las caras (código en python_code/faces.py)
faces.show_faces(image_path, detected_faces)
# Out:
# ---------------------------------------------------------------------------
# APIErrorException                         Traceback (most recent call last)
# c:\Users\Anahi\Documents\Azure-Az900\DataRangers\LabsAI.ipynb Cell 11' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000013?line=2'>3</a> image_stream = open(image_path, "rb")
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000013?line=4'>5</a> # Detectar caras
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000013?line=5'>6</a> detected_faces = client.face.detect_with_stream(image=image_stream)
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000013?line=7'>8</a> # Mostrar las caras (código en python_code/faces.py)
# ...

# %%
# Abrir una imagen
image_path ='./data/vision/humanos.jpg'
image_stream = open(image_path, "rb")

# Detectar caras
detected_faces = client.face.detect_with_stream(image=image_stream)

# Mostrar las caras (código en python_code/faces.py)
faces.show_faces(image_path, detected_faces, show_id=True)
# Out:
# ---------------------------------------------------------------------------
# APIErrorException                         Traceback (most recent call last)
# c:\Users\Anahi\Documents\Azure-Az900\DataRangers\LabsAI.ipynb Cell 12' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000014?line=2'>3</a> image_stream = open(image_path, "rb")
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000014?line=4'>5</a> # Detectar caras
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000014?line=5'>6</a> detected_faces = client.face.detect_with_stream(image=image_stream)
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000014?line=7'>8</a> # Mostrar las caras (código en python_code/faces.py)
# ...

# %%
image_path = './data/vision/humanos.jpg'
image_stream = open(image_path, "rb")

attributes = ['age', 'emotion']
detected_faces = client.face.detect_with_stream(image=image_stream, return_face_attributes=attributes)

faces.show_face_attributes(image_path, detected_faces)
# Out:
# ---------------------------------------------------------------------------
# APIErrorException                         Traceback (most recent call last)
# c:\Users\Anahi\Documents\Azure-Az900\DataRangers\LabsAI.ipynb Cell 13' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000015?line=1'>2</a> image_stream = open(image_path, "rb")
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000015?line=3'>4</a> attributes = ['age', 'emotion']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000015?line=4'>5</a> detected_faces = client.face.detect_with_stream(image=image_stream, return_face_attributes=attributes)
#       <a href='vscode-notebook-cell:/c%3A/Users/Anahi/Documents/Azure-Az900/DataRangers/LabsAI.ipynb#ch0000015?line=6'>7</a> faces.show_face_attributes(image_path, detected_faces)
#
# ...
